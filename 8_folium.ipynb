# %% [markdown]
# <a href="https://colab.research.google.com/github/leeCodingStudio/Python_data_analysis/blob/master/8_folium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. folium
# * leaflet.js 기반으로 만들어진 라이브러리
# * 지도위에 데이터를 표현해주는 대표적인 파이썬 지도 시각화 라이브러리
# * [folium.document](https://python-visualization.github.io/folium)

# %%
# !pip install folium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.27.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.4)

# %%
import folium

# %%
# folium.Map(location=[위도, 경도], zomm_start=배율, ...)
map_folium = folium.Map(location=[37.50006, 127.0355806], zoom_start=17)
map_folium
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e786aa8407175efa7ab83d2b58316378 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e786aa8407175efa7ab83d2b58316378&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e786aa8407175efa7ab83d2b58316378 = L.map(
#                 &quot;map_e786aa8407175efa7ab83d2b58316378&quot;,
#                 {
#                     center: [37.50006, 127.0355806],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ddd31eddf58d269fe0c85656ba9e41f9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e786aa8407175efa7ab83d2b58316378);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Marker(): location 속성으로 지정한 위치에 마커를 생성
# popup(): 마커를 클릭했을 때 표시할 문자열을 설정
# add_to():  작성된 마커를 지도에 추가

map_folium = folium.Map(location=[37.50000,127.0355806],zoom_start=17)
popup = folium.Popup('코리아it아카데미',max_width=200)
folium.Marker(location=[37.50000,127.0355806],popup=popup).add_to(map_folium)
map_folium
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9248bd5d2242044e786c16175a9d6bef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9248bd5d2242044e786c16175a9d6bef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9248bd5d2242044e786c16175a9d6bef = L.map(
#                 &quot;map_9248bd5d2242044e786c16175a9d6bef&quot;,
#                 {
#                     center: [37.5, 127.0355806],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c7e61d720e8988fd46997906c89f7614 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9248bd5d2242044e786c16175a9d6bef);
#
#
#             var marker_b34d067fd65b7497ab359b447ea6bc3c = L.marker(
#                 [37.5, 127.0355806],
#                 {}
#             ).addTo(map_9248bd5d2242044e786c16175a9d6bef);
#
#
#         var popup_2db0f0d426f21d900e6918308f98c42a = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_693b9ad3fc6605f38628c86cc14d158d = $(`&lt;div id=&quot;html_693b9ad3fc6605f38628c86cc14d158d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;코리아it아카데미&lt;/div&gt;`)[0];
#                 popup_2db0f0d426f21d900e6918308f98c42a.setContent(html_693b9ad3fc6605f38628c86cc14d158d);
#
#
#
#         marker_b34d067fd65b7497ab359b447ea6bc3c.bindPopup(popup_2db0f0d426f21d900e6918308f98c42a)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 지도: 37.56652479270633, 126.9779129116262
# 서울특별시청: 37.56652479270633, 126.9779129116262
# 덕수궁: 37.56585320879458, 126.97514572197248
# 서울지방경찰청: 37.57504045678939, 126.97195576938117
# 광화문: 37.57617987638928, 126.97694467807803
# 영풍문고-종로본점: 37.56999947440024, 126.98228391170936
from folium.features import CustomIcon

icon_image = 'batman.png'
icon = CustomIcon(icon_image, icon_size=(45, 45))

map_folium = folium.Map(location=[37.56652479270633, 126.9779129116262],zoom_start=15)

popup = folium.Popup('서울특별시청',max_width=200)
folium.Marker(location=[37.56652479270633, 126.9779129116262],popup=popup,
              icon = folium.Icon(color='red', icon='star')).add_to(map_folium)

popup = folium.Popup('덕수궁',max_width=200)
folium.Marker(location=[37.56585320879458, 126.97514572197248],popup=popup,
              icon = folium.Icon(color='pink', icon='ok')).add_to(map_folium)

popup = folium.Popup('서울지방경찰청',max_width=200)
folium.Marker(location=[37.57504045678939, 126.97195576938117],popup=popup,
              icon = icon).add_to(map_folium)

popup = folium.Popup('광화문',max_width=200)
folium.Marker(location=[37.57617987638928, 126.97694467807803],popup=popup).add_to(map_folium)

popup = folium.Popup('영풍문고-종로본점',max_width=200)
folium.Marker(location=[37.56999947440024, 126.98228391170936],popup=popup).add_to(map_folium)
map_folium
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4dbd34b429f1cf79c51cc5c6c51c12bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4dbd34b429f1cf79c51cc5c6c51c12bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4dbd34b429f1cf79c51cc5c6c51c12bf = L.map(
#                 &quot;map_4dbd34b429f1cf79c51cc5c6c51c12bf&quot;,
#                 {
#                     center: [37.56652479270633, 126.9779129116262],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a426c7f1e972a4599457f9c88c75ddd7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4dbd34b429f1cf79c51cc5c6c51c12bf);
#
#
#             var marker_8022d8165b1a06e5749e08955ca5baac = L.marker(
#                 [37.56652479270633, 126.9779129116262],
#                 {}
#             ).addTo(map_4dbd34b429f1cf79c51cc5c6c51c12bf);
#
#
#             var icon_99db2f2093d24767073c3720f30f9cd5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8022d8165b1a06e5749e08955ca5baac.setIcon(icon_99db2f2093d24767073c3720f30f9cd5);
#
#
#         var popup_d625616148f9ef9ca29677fb83e257e1 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_02555dd372cc0e10bf54b93a7d50da7c = $(`&lt;div id=&quot;html_02555dd372cc0e10bf54b93a7d50da7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시청&lt;/div&gt;`)[0];
#                 popup_d625616148f9ef9ca29677fb83e257e1.setContent(html_02555dd372cc0e10bf54b93a7d50da7c);
#
#
#
#         marker_8022d8165b1a06e5749e08955ca5baac.bindPopup(popup_d625616148f9ef9ca29677fb83e257e1)
#         ;
#
#
#
#
#             var marker_b0fa55641fe07034157b60a66e23ca92 = L.marker(
#                 [37.56585320879458, 126.97514572197248],
#                 {}
#             ).addTo(map_4dbd34b429f1cf79c51cc5c6c51c12bf);
#
#
#             var icon_66c1d02f474af0cd35a7ad9c39983e83 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b0fa55641fe07034157b60a66e23ca92.setIcon(icon_66c1d02f474af0cd35a7ad9c39983e83);
#
#
#         var popup_d72fbe36052f3e6ad1fbcf0d439f0082 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_e12e343f73130bdf87f4cafb3f6ed3bf = $(`&lt;div id=&quot;html_e12e343f73130bdf87f4cafb3f6ed3bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;덕수궁&lt;/div&gt;`)[0];
#                 popup_d72fbe36052f3e6ad1fbcf0d439f0082.setContent(html_e12e343f73130bdf87f4cafb3f6ed3bf);
#
#
#
#         marker_b0fa55641fe07034157b60a66e23ca92.bindPopup(popup_d72fbe36052f3e6ad1fbcf0d439f0082)
#         ;
#
#
#
#
#             var marker_9dfd348d3a42af161ac48df9ab0462cb = L.marker(
#                 [37.57504045678939, 126.97195576938117],
#                 {}
#             ).addTo(map_4dbd34b429f1cf79c51cc5c6c51c12bf);
#
#
#         var custom_icon_981dad89125cb9eb7094fca19f5b70c4 = L.icon({&quot;iconSize&quot;: [45, 45], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_9dfd348d3a42af161ac48df9ab0462cb.setIcon(custom_icon_981dad89125cb9eb7094fca19f5b70c4);
#
#
#         var popup_fb3170457a8b2e7b03e26cd34bf9a480 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_d36791cf8920f1d95d6af7322b39b6bb = $(`&lt;div id=&quot;html_d36791cf8920f1d95d6af7322b39b6bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울지방경찰청&lt;/div&gt;`)[0];
#                 popup_fb3170457a8b2e7b03e26cd34bf9a480.setContent(html_d36791cf8920f1d95d6af7322b39b6bb);
#
#
#
#         marker_9dfd348d3a42af161ac48df9ab0462cb.bindPopup(popup_fb3170457a8b2e7b03e26cd34bf9a480)
#         ;
#
#
#
#
#             var marker_944bb36b91b524ae95f57d79e6a1e042 = L.marker(
#                 [37.57617987638928, 126.97694467807803],
#                 {}
#             ).addTo(map_4dbd34b429f1cf79c51cc5c6c51c12bf);
#
#
#         var popup_3ae3496ca1f682b97a88b30a799dca0d = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_4950d844934c6a5c8807c9aa402a08ec = $(`&lt;div id=&quot;html_4950d844934c6a5c8807c9aa402a08ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광화문&lt;/div&gt;`)[0];
#                 popu

# %%
# CircleMarker(): 원의 범위를 마커로 생성
map_folium = folium.Map(location=[37.56652479270633, 126.9779129116262],zoom_start=15)

popup = folium.Popup('서울특별시청',max_width=200)
folium.CircleMarker(location=[37.56652479270633, 126.9779129116262],popup=popup,
              radius=100, color='red', fill_color='#EC4074').add_to(map_folium)

map_folium
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc9692bbba577e486c3cc5fab8289ff8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc9692bbba577e486c3cc5fab8289ff8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dc9692bbba577e486c3cc5fab8289ff8 = L.map(
#                 &quot;map_dc9692bbba577e486c3cc5fab8289ff8&quot;,
#                 {
#                     center: [37.56652479270633, 126.9779129116262],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_66616d96be3046b7014de8d217a79ddb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dc9692bbba577e486c3cc5fab8289ff8);
#
#
#             var circle_marker_0f5cb562072394f9563a174e5b1676d7 = L.circleMarker(
#                 [37.56652479270633, 126.9779129116262],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#EC4074&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dc9692bbba577e486c3cc5fab8289ff8);
#
#
#         var popup_c7c2a362cdd27c106b448763114e8d7c = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_369caf9e18d9cb4725bedcf56f1a6d5f = $(`&lt;div id=&quot;html_369caf9e18d9cb4725bedcf56f1a6d5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시청&lt;/div&gt;`)[0];
#                 popup_c7c2a362cdd27c106b448763114e8d7c.setContent(html_369caf9e18d9cb4725bedcf56f1a6d5f);
#
#
#
#         circle_marker_0f5cb562072394f9563a174e5b1676d7.bindPopup(popup_c7c2a362cdd27c106b448763114e8d7c)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 2. folium 활용

# %%
import pandas as pd

# %%
library = pd.read_csv('/content/drive/MyDrive/KDT/2. 데이터분석/data.csv')

# %%
library
# Out:
#      고유번호   구명   법정동명  산지여부  주지번  부지번                 새주소명  \
# 0      21  구로구   구로3동     1  777    1  구로구 디지털로 27다길 65 2층
# 1      22  용산구    후암동     1   30   84        용산구 후암동 30-84
# 2      23   중구    신당동     1  844                 중구 다산로 32
# 3      24  노원구  상계10동     1  686                노원구 온곡길 21
# 4      25  노원구   중계3동     1  508              노원구 중계3동 508
# ..    ...  ...    ...   ...  ...  ...                  ...
# 118   118  광진구    중곡동     1  168    8           광진구 능동로 16
# 119   119   중구    신당동     1   52  164      중구 다산로38길 66-35
# 120   121  강남구   대치4동     1  928   22      강남구 도곡로 북49길 23
# 121   122  은평구    증산동     1  173    8          은평구 증산로5길 6
# 122   123  강남구    청담동     1  124    1      강남구 압구정로동50길 26
#
#                     시설명              운영기관 설립주체    시설구분         개관일      면적  \
# 0               꿈마을 도서관        구로구 시설관리공단        구립도서관  2007-04-05   476.0
# 1                남산 도서관                         교육청도서관  1922-10-05     0.0
# 2    남산타운 문화체육센터 어린이도서관            시설관리공단        구립도서관  2010-04-01   273.8
# 3              노원 정보도서관         노원 교육복지재단        구립도서관  2006-02-15  6526.0
# 4              노원 평생학습관                         교육청도서관  1990-05-08     0.0
# ..                  ...               ...  ...     ...         ...     ...
# 118       중곡 문화체육센터 도서관        광진구 시설관리공단        구립도서관  2008-10-27  1320.0
# 119        중구 구립 신당 도서관            시설관리공단        구립도서관  2011-03-24  1557.4
# 120             즐거운 도서관  (사)작은도서관 만드는 사람들        구립도서관  2004-09-01   325.0
# 121            증산 정보도서관        사회복지법인 인덕원        구립도서관  2008-10-09  2110.0
# 122              청담 도서관  (사)작은도서관 만드는 사람들        구립도서관  1999-10-11   348.0
#
#                           홈페이지주소           연락처 생성일          경도         위도
# 0      lib.guro.go.kr/dreamtown/      830-5807      126.890115  37.487220
# 1    lib.sen.go.kr/lib_index.jsp                    126.981375  37.552664
# 2          www.e-junggulib.or.kr  02-2280-8520      127.009297  37.549020
# 3                www.nowonlib.kr   02-950-0029      127.064177  37.660927
# 4    lib.sen.go.kr/lib_index.jsp                    127.067120  37.640120
# ..                           ...           ...  ..         ...        ...
# 118         gwangjinlib.seoul.kr     3408-4900      127.084751  37.567803
# 119        www.e-junggulib.or.kr  02-2280-9240      127.018969  37.561726
# 120        library.gangnam.go.kr   02-565-7533      127.057872  37.499750
# 121             www.jsplib.or.kr   02-307-6030      126.907643  37.582804
# 122        library.gangnam.go.kr   02-540-7042      127.049339  37.525094
#
# [123 rows x 18 columns]

# %%
map = folium.Map(location=[37.58, 127.0], zoom_start=11)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e92bcc33030f2ddb2ae7ea88bea881b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e92bcc33030f2ddb2ae7ea88bea881b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8e92bcc33030f2ddb2ae7ea88bea881b = L.map(
#                 &quot;map_8e92bcc33030f2ddb2ae7ea88bea881b&quot;,
#                 {
#                     center: [37.58, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4042c2b6e4c93546231b422e86dd452b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8e92bcc33030f2ddb2ae7ea88bea881b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location=[37.58, 127.0], zoom_start=11)

for _, row in library.iterrows():
    icon_image = 'library.png'
    icon = CustomIcon(icon_image, icon_size=(45, 45))
    
    popup = folium.Popup(row['시설명'], max_width=200)
    folium.Marker(location=[row['위도'], row['경도']], popup=popup, icon=icon).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ed6038a185762aff82e68070654b700 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ed6038a185762aff82e68070654b700&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ed6038a185762aff82e68070654b700 = L.map(
#                 &quot;map_3ed6038a185762aff82e68070654b700&quot;,
#                 {
#                     center: [37.58, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6d969babddf86c947d690d9e47e2d4b5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3ed6038a185762aff82e68070654b700);
#
#
#             var marker_36bd78ceec0147e91b100e6598fabbbd = L.marker(
#                 [37.4872202, 126.8901147],
#                 {}
#             ).addTo(map_3ed6038a185762aff82e68070654b700);
#
#
#         var custom_icon_c256cb292b1739641a7fb990d54bebaf = L.icon({&quot;iconSize&quot;: [45, 45], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_36bd78ceec0147e91b100e6598fabbbd.setIcon(custom_icon_c256cb292b1739641a7fb990d54bebaf);
#
#
#         var popup_926c44eb22f3ec29ce7b92ad16d411c1 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_119c7e007c6a8d52e40cd51556dd1a20 = $(`&lt;div id=&quot;html_119c7e007c6a8d52e40cd51556dd1a20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;꿈마을 도서관&lt;/div&gt;`)[0];
#                 popup_926c44eb22f3ec29ce7b92ad16d411c1.setContent(html_119c7e007c6a8d52e40cd51556dd1a20);
#
#
#
#         marker_36bd78ceec0147e91b100e6598fabbbd.bindPopup(popup_926c44eb22f3ec29ce7b92ad16d411c1)
#         ;
#
#
#
#
#             var marker_c21b6f5badae3ae1a84fe2395667a73a = L.marker(
#                 [37.5526641, 126.9813754],
#                 {}
#             ).addTo(map_3ed6038a185762aff82e68070654b700);
#
#
#         var custom_icon_2a4ad609a561e5a9301250628829eaa1 = L.icon({&quot;iconSize&quot;: [45, 45], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_c21b6f5badae3ae1a84fe2395667a73a.setIcon(custom_icon_2a4ad609a561e5a9301250628829eaa1);
#
#
#         var popup_a0f14f7345d3c5a2ca5abd74522706f4 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_39e991d59529995db54957ba7e3faad5 = $(`&lt;div id=&quot;html_39e991d59529995db54957ba7e3faad5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;남산 도서관&lt;/div&gt;`)[0];
#                 popup_a0f14f7345d3c5a2ca5abd74522706f4.setContent(html_39e991d59529995db54957ba7e3faad5);
#
#
#
#         marker_c21b6f5badae3ae1a84fe2395667a73a.bindPopup(popup_a0f14f7345d3c5a2ca5abd74522706f4)
#         ;
#
#
#
#
#             var marker_4bb3f9b12e2b89af8319db62d050101e = L.marker(
#                 [37.5490198, 127.0092967],
#                 {}
#             ).addTo(map_3ed6038a185762aff82e68070654b700);
#
#
#         var custom_icon_644d9677c223d8d48a51b4f02e24de1f = L.icon({&quot;iconSize&quot;: [45, 45], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_4bb3f9b12e2b89af8319db62d050101e.setIcon(custom_icon_644d9677c223d8d48a51b4f02e24de1f);
#
#
#         var popup_c7493c088796f70aabaed31dce87808a = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_e8abf986ad3a892a60d9ad6489f7f9e7 = $(`&lt;div id=&quot;html_e8abf986ad3a892a60d9ad6489f7f9e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;남산타운 문화체육센터 어린이도서관&lt;/div&gt;`)[0];
#                 popup_c7493c088796f70aabaed31dce87808a.setContent(html_e8abf986ad3a892a60d9ad6489f7f9e7);
#
#
#
#         marker_4bb3f9b12e2b89af8319db62d050101e.bindPopup(popup_c7493c088796f70aabaed31dce87808a)
#         ;
#
#
#
#
#             var marker_6e56055415fa17c9d67c2b8cd4878872 = L.marker(
#                 [37.6609272, 127.0641766],
#                 {}
#             ).addTo(map_3ed6038a185762aff82e68070654b700);
#
#
#         var custom_icon_ae7256ba394a66cdaaabde689231693a = L.icon({&quot;iconSize&quot;: [45, 45], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_6e56055415fa17c9d67c2b8cd4878872.setIcon(custom_icon_ae7256ba394a66cdaaabde689231693a);
#
#
#         var popup_54fdae2bbfb144031c35031c07a0410a = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_f3a46995ec55b4f04edc13dc7407a5b4 = $(`&lt;div id=&quot;html_f3a46995ec55b4f04edc13dc7407a5b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;노원 정보도서관&lt;/div&gt;`)[0];
#                 popup_54fdae2bbfb144031c35031c07a0410a.setContent(html_f3a46995ec55b4f04edc13dc7407a5b4);

# %%
# MarkerCluster
from folium.plugins import MarkerCluster
mc=MarkerCluster()
for _, row in library.iterrows():
  icon_image = 'library.png'
  icon = CustomIcon(icon_image, icon_size=(45,45))
  popup = folium.Popup(row['시설명'], max_width=200)
  folium.Marker(location=[row['위도'], row['경도']], popup=row['시설명'], icon=icon)
  map.add_child(mc)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37e123a58ea67fe5382fbe7035cad3b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37e123a58ea67fe5382fbe7035cad3b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_37e123a58ea67fe5382fbe7035cad3b6 = L.map(
#                 &quot;map_37e123a58ea67fe5382fbe7035cad3b6&quot;,
#                 {
#                     center: [37.58, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d62c1b6b52dccd8979a28d88b4c9941 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_37e123a58ea67fe5382fbe7035cad3b6);
#
#
#             var marker_cluster_b69a8246a893b614ccfd94ea8c33b89e = L.markerClusterGroup(
#                 {}
#             );
#             map_37e123a58ea67fe5382fbe7035cad3b6.addLayer(marker_cluster_b69a8246a893b614ccfd94ea8c33b89e);
#
#
#             var marker_723ff03693a5e754f007634ce6d571ac = L.marker(
#                 [37.4872202, 126.8901147],
#                 {}
#             ).addTo(marker_cluster_b69a8246a893b614ccfd94ea8c33b89e);
#
#
#         var custom_icon_aab0d117eee447278ee6535813db83c2 = L.icon({&quot;iconSize&quot;: [45, 45], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_723ff03693a5e754f007634ce6d571ac.setIcon(custom_icon_aab0d117eee447278ee6535813db83c2);
#
#
#         var popup_22cc3a6010fdf494bb186e40090e598e = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_a0a13eceebe2aac7bf59b50b6672f30c = $(`&lt;div id=&quot;html_a0a13eceebe2aac7bf59b50b6672f30c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;꿈마을 도서관&lt;/div&gt;`)[0];
#                 popup_22cc3a6010fdf494bb186e40090e598e.setContent(html_a0a13eceebe2aac7bf59b50b6672f30c);
#
#
#
#         marker_723ff03693a5e754f007634ce6d571ac.bindPopup(popup_22cc3a6010fdf494bb186e40090e598e)
#         ;
#
#
#
#
#             var marker_0558d8178e4359f1ee45572be76f088a = L.marker(
#                 [37.5526641, 126.9813754],
#                 {}
#             ).addTo(marker_cluster_b69a8246a893b614ccfd94ea8c33b89e);
#
#
#         var custom_icon_72c7e73cd4ccdf9f2f4756dcd9b95c81 = L.icon({&quot;iconSize&quot;: [45, 45], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_0558d8178e4359f1ee45572be76f088a.setIcon(custom_icon_72c7e73cd4ccdf9f2f4756dcd9b95c81);
#
#
#         var popup_56e6f2d594daafe22ee916d797e163aa = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_75f96e62d48e6aba16b37a5320cc052d = $(`&lt;div id=&quot;html_75f96e62d48e6aba16b37a5320cc052d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;남산 도서관&lt;/div&gt;`)[0];
#                 popup_56e6f2d594daafe22ee916d797e163aa.setContent(html_75f96e62d48e6aba16b37a5320cc052d);
#
#
#
#         marker_0558d8178e4359f1ee45572be76f088a.bindPopup(popup_56e6f2d594daafe22ee916d797e163aa)
#         ;
#
#
#
#
#             var marker_b627e31267c77319052539d2850e9d92 = L.marker(
#                 [37.5490198, 127.0092967],
#                 {}
#             ).addTo(marker_cluster_b69a8246a893b614ccfd94ea8c33b89e);
#
#
#         var custom_icon_c6a5fb97262c65ec3617f9494671007a = L.icon({&quot;iconSize&quot;: [45, 45], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_b627e31267c77319052539d2850e9d92.setIcon(custom_icon_c6a5fb97262c65ec3617f9494671007a);
#
#
#         var popup_ccbf30be215956ef5c204d89e7acc876 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_53ec507c86f0b328145232b69586b560 = $(`&lt;div id=&quot;html_53ec507c86f0b328145232b69586b560&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;남산타운 문화체육센터 어린이도서관&lt;/div&gt;`)[0];
#                 popup_ccbf30be215956ef5c204d89e7acc876.setContent(html_53ec507c86f0b328145232b69586b560);
#
#
#
#         marker_b627e31267c77319052539d2850e9d92.bindPopup(popup_ccbf30be215956ef5c204d89e7acc876)
#         ;
#
#
#
#
#             var marker_dcf89bd51a6d7865035bc4f7def0d1a2 = L.marker(
#                 [37.6609272, 127.0641766],
#                 {}
#             ).addTo(marker_cluster_b69a8246a893b614ccfd94ea8c33b89e);

# %%
# 서클마커로 도서관 표시하기
# 2010년 이후 개장: 파란색
# 2010년 이전 개장: 빨간색

def select_color(row):
    year = int(row['개관일'].split('-')[0])
    if year > 2010:
        return 'blue'
    else:
        return 'red'
map = folium.Map(location=[37.58, 127.0], zoom_start=13)
for _, row in library.iterrows():
    popup = folium.Popup(row['시설명'], max_width=200)
    folium.Circle(location=[row['위도'], row['경도']], popup=popup, radius=200, color=select_color(row),
                  fill_color=select_color(row)).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_34c74a09a042730e8e28eebb577cfb44 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_34c74a09a042730e8e28eebb577cfb44&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_34c74a09a042730e8e28eebb577cfb44 = L.map(
#                 &quot;map_34c74a09a042730e8e28eebb577cfb44&quot;,
#                 {
#                     center: [37.58, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_65886ffe042a3d058cd1c14d2b48d01e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_34c74a09a042730e8e28eebb577cfb44);
#
#
#             var circle_d3a8df98692851dea05df21d01803617 = L.circle(
#                 [37.4872202, 126.8901147],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 200, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_34c74a09a042730e8e28eebb577cfb44);
#
#
#         var popup_308f24f16e84735d92dc79d80d666d9c = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_e9b8b81f093cab32324235140cea3e36 = $(`&lt;div id=&quot;html_e9b8b81f093cab32324235140cea3e36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;꿈마을 도서관&lt;/div&gt;`)[0];
#                 popup_308f24f16e84735d92dc79d80d666d9c.setContent(html_e9b8b81f093cab32324235140cea3e36);
#
#
#
#         circle_d3a8df98692851dea05df21d01803617.bindPopup(popup_308f24f16e84735d92dc79d80d666d9c)
#         ;
#
#
#
#
#             var circle_03e7a06b39a4394a45cfa0f740f003ef = L.circle(
#                 [37.5526641, 126.9813754],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 200, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_34c74a09a042730e8e28eebb577cfb44);
#
#
#         var popup_95ffddd31188924d3576abb10d7916fb = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_43088cf6508908d036e753dbcb9fcb33 = $(`&lt;div id=&quot;html_43088cf6508908d036e753dbcb9fcb33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;남산 도서관&lt;/div&gt;`)[0];
#                 popup_95ffddd31188924d3576abb10d7916fb.setContent(html_43088cf6508908d036e753dbcb9fcb33);
#
#
#
#         circle_03e7a06b39a4394a45cfa0f740f003ef.bindPopup(popup_95ffddd31188924d3576abb10d7916fb)
#         ;
#
#
#
#
#             var circle_a52a15d2278c0afab521bc8f0002202f = L.circle(
#                 [37.5490198, 127.0092967],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 200, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_34c74a09a042730e8e28eebb577cfb44);
#
#
#         var popup_270c7beebff76711bdf7f6333b33938a = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_18fc67faab87cae1078c236e70d5d0d9 = $(`&lt;div id=&quot;html_18fc67faab87cae1078c236e70d5d0d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;남산타운 문화체육센터 어린이도서관&lt;/div&gt;`)[0];
#                 popup_270c7beebff76711bdf7f6333b33938a.setContent(html_18fc67faab87cae1078c236e70d5d0d9);
#
#
#
#         circle_a52a15d2278c0afab521bc8f0002202f.bindPopup(popup_270c7beebff76711bdf7f6333b33938a)
#         ;
#
#
#
#
#             var circle_fc94ff865a43df52d10328bacb4cce88 = L.circle(
#                 [37.6609272, 127.0641766],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot
